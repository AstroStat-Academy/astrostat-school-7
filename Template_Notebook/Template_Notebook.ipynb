# %% [markdown]
# <fieldset style="padding:10px; border:1px solid #ccc; box-shadow:2px 2px 5px rgba(0,0,0,0.1);">
# <legend style="font-size: 10px; color:#555;">Credits</legend>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <td style="width: 80px; vertical-align: top;">
#             <img src="https://raw.githubusercontent.com/AstroStat-Academy/assets-public/main/logo/logo_b_text_lowres.png" alt="AstroStat Academy logo" width="100">
#         </td>
#         <td style="vertical-align: center; padding-left: 15px; font-size: 10px; line-height: 1.2;">
#             This notebook contains original work by the authors unless stated otherwise.
#             Any external material is properly credited to its sources.<br>
#             References to papers, datasets, and software are acknowledged.
#             Original content is licensed under the <a href="https://www.gnu.org/licenses/gpl-3.0.en.html">GNU General Public License v3.0 (GNU GPLv3)</a>.
#         </td>
#     </tr>
# </table>
#
# </fieldset>
# <!-- Allow these <br> or it will look ugly once rendered on Jupyter Book. -->
# <br>

# %% [markdown]
# <fieldset style="padding:10px; border:1px solid #ccc; background-color: rgba(196, 164, 132, 0.2); box-shadow:2px 2px 5px rgba(0,0,0,0.1);">
#
# <legend style="font-size: 10px; color:#555;">[INSTRUCTIONS]</legend>
#
# Blocks like this one – with the legend tag "**INSTRUCTIONS**" – are used in this document to comment on the template gimmicks. All the rest of the material shall be considered as example text/code than may appear in an actual lecture. That includes the "Credits" block above, that shall be present in every notebook.
#
# If the additional tag "**OPTIONAL**" is present, that instruction is up to the creator to follow.
#
# If you are a teacher, an LLM, or an AI Agent, use these blocks to get general guidance.
#
# </fieldset>

# %% [markdown]
# <fieldset style="padding:10px; border:1px solid #ccc; background-color: rgba(196, 164, 132, 0.2); box-shadow:2px 2px 5px rgba(0,0,0,0.1);">
#
# <legend style="font-size: 10px; color:#555;">[INSTRUCTIONS]</legend>
#
# **Title**<br>
# If you inspect the title, you will see it is not preceeded by a "#" $\rightarrow$ In this way, it does not appear it in the Table of Content as a chapter.
#
# Additionally, this reserves "#" for actual chapters.
#
# </fieldset>

# %% [markdown]
# <fieldset style="padding:10px; border:1px solid #ccc; background-color: rgba(196, 164, 132, 0.2); box-shadow:2px 2px 5px rgba(0,0,0,0.1);">
#
# <legend style="font-size: 10px; color:#555;">[INSTRUCTIONS][OPTIONAL]</legend>
#
# **Right under the title**<br>
# Here it may go an extremely short summary (e.g., bullet points) of what will be shown in the notebook.
#
# </fieldset>

# %% [markdown]
# <font size=6>**Example of Long Title - Hands On**</font>
#
# In this notebook we will see ...
#
# - How to use color blocks
# - Concept A
# - Some actual code

# %% [markdown]
# # Color Blocks

# %% [markdown]
# <fieldset style="padding:10px; border:1px solid #ccc; background-color: rgba(196, 164, 132, 0.2); box-shadow:2px 2px 5px rgba(0,0,0,0.1);">
#
# <legend style="font-size: 10px; color:#555;">[INSTRUCTIONS][OPTIONAL]</legend>
#
# Color blocks are not mandatory, but they are fancy :D<br>
# Do not attempt to make your custom boxes: these ones have been tested to run on Jupyter, Colab, Jupyter Book, and GitHub preview.
#
# **Info block**<br>
# You can use the blue or green, but stick to the same color throughout a notebook.
#
# One possible usage it to reserve the <strong>blue</strong> info style for lenghty demonstrations (<i>possibly as a collapsable item $-$ see below</i>), and **green** for something else.
#
# **Warning block**<br>
# You can use one to point out something that the student needs to do (_e.g., import the library_), something that the student needs to know when looking at the code afterwards (_e.g., this library shall be installed via cuda, not pip_), or a spoiler.
#
# </fieldset>

# %% [markdown]
# <fieldset style="padding:10px; border:1px solid #ccc; background-color: rgba(196, 164, 132, 0.2); box-shadow:2px 2px 5px rgba(0,0,0,0.1);">
#
# <legend style="font-size: 10px; color:#555;">[INSTRUCTIONS]</legend>
#
# **Exercise block**<br>
# The orange blocks are reserved for exercises (_see later_).
#
# </fieldset>

# %% [markdown]
# <div style="border-left: 4px solid #4CAF50; padding-left: 1em; padding-top: 1em; padding-bottom: 1em; margin: 1em 0; background: #e8f5e9">
#
# **NOTE:** This function is not differentiable.
#
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #2196F3; padding-left: 1em; padding-top: 1em; padding-bottom: 1em; margin: 1em 0; background: #f0f8ff">
#
# **NOTE:** This function is not differentiable.
#
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #2196F3; padding-left: 1em; padding-top: 1em; padding-bottom: 1em; margin: 1em 0; background: #f0f8ff">
#
# <details>
#
# <b><summary>[Proof] (click here to expand)</summary></b>
#
# Proving that the result gives 4.
#
# Let $x = 3$, then:
#
# $x + 1 = 4$ $~$ &#9632;
#
# </details>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #e57373; padding-left: 1em; padding-top: 1em; padding-bottom: 1em; margin: 1em 0; background: #fdecea">
#
# **WARNING:** This requires a GPU.
#
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #e57373; padding-left: 1em; padding-top: 1em; padding-bottom: 1em; margin: 1em 0; background: #fdecea">
# <details>
#
# <b><summary>[Spoiler] (click here to expand)</summary></b>
#
# The answer was 50%.
#
# </details>
# </div>

# %% [markdown]
# # Setup

# %% [markdown]
# <fieldset style="padding:10px; border:1px solid #ccc; background-color: rgba(196, 164, 132, 0.2); box-shadow:2px 2px 5px rgba(0,0,0,0.1);">
#
# <legend style="font-size: 10px; color:#555;">[INSTRUCTIONS][OPTIONAL]</legend>
#
# The following snippet is used to set a global plot style (_fancy backgrounds, font size, etc._) so you do not have to do it for every plot.
#
# Notably, in any code block you can just just invoke any `plt.<>()` function without declaring a `plt.figure` (_but you will have to, if you want to use_ `plt.subplots`).
#
# This will also import `matplotlib` and `seaborn`, therefore those libraries shall <u>not</u> be imported again later on the notebook (_or run another_ `exec(set_style)`).
#
# </div>

# %%
import requests

url = "https://raw.githubusercontent.com/AstroStat-Academy/assets-public/main/styles/plot_style.py"
style = requests.get(url).text
exec(style)
# Out:
# Imported matplotlib.
# Imported saborn.
# Plotting style set.

# %% [markdown]
# # Section
#
# ## Sub-section
#
# <u>**Sub-sub-section**</u>

# %% [markdown]
# <fieldset style="padding:10px; border:1px solid #ccc; background-color: rgba(196, 164, 132, 0.2); box-shadow:2px 2px 5px rgba(0,0,0,0.1);">
#
# <legend style="font-size: 10px; color:#555;">[INSTRUCTIONS][OPTIONAL]</legend>
#
#
# As markdown titles, you shall strive to nest at most until sub-sections, since it becomes ugly real fast.
#
# For anything after that (_sub-sub-..._), use underling, capital letters, boldface or whatever else you like.
# </div>

# %% [markdown]
# # Text

# %% [markdown]
# <fieldset style="padding:10px; border:1px solid #ccc; background-color: rgba(196, 164, 132, 0.2); box-shadow:2px 2px 5px rgba(0,0,0,0.1);">
#
# <legend style="font-size: 10px; color:#555;">[INSTRUCTIONS][OPTIONAL]</legend>
#
# Try not to produce long text chunks: they are literally impossible for the students to read through, while they listen to you.
#
# Ideally:
# - Write 1-2 short sentences and then leave a space.
# - Alternate sentences with other things: _code snippets_, _indented blocks_, _color blocks_, etc.
# - Adding 1 **bold** word per sentence helps visual guiding and yourself during presentation.
#
# If you really need to add long chunks of text for lenghty explanations, add them inside a collapsable block (_see above_).
#
# </div>

# %% [markdown]
# We study the **mean** as a central summary of data.<br>
# It represents the typical value in a dataset and gives a quick sense of where observations are concentrated.
#
# ```python
# import numpy as np
# np.mean([1, 2, 3, 4, 5])
# ```
#
# The **variance** measures how spread out values are around the mean.<br>
# It captures the average squared deviation, so larger values indicate more dispersion.
#
# > _NOTE: Variance is sensitive to extreme values and can be inflated by outliers._
#
# The **standard deviation** is the square root of variance.<br>
# It provides a more interpretable measure of spread since it is expressed in the same units as the data.
#
# $\rightarrow$ The latter two are strongly connected.
#
# <details>
# <summary>More details</summary>
#
# The mean is computed as the sum of all observations divided by their number.
# Variance quantifies dispersion by averaging squared distances from the mean.
# Standard deviation rescales this quantity, making it easier to compare with the original data.
#
# </details>

# %% [markdown]
# # Figures
#
# You may import figures in 2 ways:
#
# 1. Old school, by importing them from an "**images**" folder (_use this name_):
# ```bash
# ![figure](./imgages/my_plot.png)
# ```
# > With this method, you will have to upload all the images, and a user has to download both the notebook _and_ the image folder.
#
# 2. Via **drag & drop** on a markdwon cell (_if it doesn't work, your cell is a code cell $\rightarrow$ change its type_)
#
# > With this method, the image gets _embedded_ in the notebook, so no external files are needed.
#
# ## Drag & Drop
#
# - You can embed only 1 figure per markdown cell $-$ add a cell if you want to embed another figure
#
# - When you drag & drop inside the cell, a text like the following will appear:
#
# ```bash
#     ![image.png](attachment:20c7fcd3-00bb-4259-a9ea-e5ccd0d9a77b.png)
# ```
#
# PS: This is some insanity of Jupyter Notebook v7, since the in v6 the actual figure name appeared after "attachment".
#
# ## Centering figures + captions
#
# Any figure we did not create shall be properly referenced.
#
# That means adding a caption $-$ we can do it by wrapping the image in a table:
#
# ```bash
# <table><tr>
#         <td width="800" style="text-align: center;">
#             <img src="attachment:20c7fcd3-00bb-4259-a9ea-e5ccd0d9a77b.png" alt="image.png">
#         </td>
# </tr></table>
# <table><tr>
#     <td width="600" style="text-align: center;">
#         <br>
#         Figure 1. Architecture of the original Transformer.
#         <br>
#         (Adapted from Figure 1 in <a href="https://arxiv.org/abs/1706.03762">Vaswani et al. 2017</a>)
#     </td>
# </tr></table>
# ```
#
# Notice that here you can also select the size of the image and that of the caption, separately.
#
# The result is as follows:

# %% [markdown]
# <table><tr>
#         <td width="800" style="text-align: center;">
#             <img src="attachment:0c4bfd36-0ff3-4d2b-92c9-9384e14ca12f.png" alt="image.png">
#         </td>
# </tr></table>
# <table><tr>
#     <td width="600" style="text-align: center;">
#         <br>
#         Figure 1. Architecture of the original Transformer.
#         <br>
#         (Adapted from Figure 1 in <a href="https://arxiv.org/abs/1706.03762">Vaswani et al. 2017</a>)
#     </td>
# </tr></table>

# %% [markdown]
# To make this work when you drag & drop, do it in this **exact order**:
#
# 1. Drag & drop $\rightarrow$ You will see `![image.png](attachment:20c7fcd3-00bb-4259-a9ea-e5ccd0d9a77b.png)`
# 2. Execute the cell $\rightarrow$ The image will be rendered
# 3. Edit the cell, copy the table above inside the cell, somewhere
# 4. Copy the text `attachment:...png`from your image into the table
# 5. Delete the `![image.png](...)` text $\rightarrow$ Only the image in the table will be left
#
# Looks tricky, but once you get the gist, it is a breeze.

# %% [markdown]
# <div class="alert alert-warning" role="alert" style="border-radius: 8px; padding: 10px">
#
# # In-class Exercise: [20 min]
#
# **Objective:** Learn how Grid Search can be used to find a model's hyperparameters.
#
# **Taks:** You shall use the provided data and train a Random Forest classifier with optimal parameters.
#
# _In particular, you must:_
#
# 1. Pick a parameter grid
# 2. Run the search
# 3. Return the best score
#
# **Data:** The mock data created below.
#
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #C4A484; background-color: rgba(196, 164, 132, 0.2); padding: 10px; border-radius: 4px; color: inherit;">
#
# **[INSTRUCTIONS]**<br>
#
# **Time**
#
# An estimate of the completion time, in minutes (_e.g., 20 min_) helps the teacher to reserve time outside the theoretical presentation, and the students to understand how much it is expected from them (_usually, it helps them to avoid overthinking_).
#
# IMPORTANT: <u>Largely overestimate the time</u> $-$ Consider that many students <u>saw your topic for the first time</u>.
#
# &emsp;&emsp;&emsp; Out of experience: they will waste 3-5 minutes just scrolling up to re-read the code/formulas you just showed.
#
# **Objective**
#
# General idea of what you want them to learn, with this exercise.
#
# **Task**
#
# Specific operations that the students need to carry out.
#
# - The more detailed, the better
# - The less detailed, the more questions you will receive, and the more times you will have to interrupt the exercise to explain again
#
# That is why it is better to split the task in smaller ones, to be executed **sequentially**.
#
# Ideally, the sequence (1, 2, 3, ..) shall be mirrored in the answerkey (_see later_)
#
# **Data**
#
# Minimal info just to give the context, no need to explain their derivation as in a scientific publication $-$ they are the _means_ to the exercise, not the objective.
#
# </div>

# %%
###EOF

# %%
###EOF
